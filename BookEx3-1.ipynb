# %%
import pandas as pd

# %%
m_data = pd.read_pickle('mortality_prepped.pkl')
m_data
# Out:
#      Year     AgeGroup  DeathRate  MeanCentered
# 0    1900  01-04 Years     1983.8    1790.87584
# 1    1901  01-04 Years     1695.0    1502.07584
# 2    1902  01-04 Years     1655.7    1462.77584
# 3    1903  01-04 Years     1542.1    1349.17584
# 4    1904  01-04 Years     1591.5    1398.57584
# ..    ...          ...        ...           ...
# 471  2014  15-19 Years       45.5    -147.42416
# 472  2015  15-19 Years       48.3    -144.62416
# 473  2016  15-19 Years       51.2    -141.72416
# 474  2017  15-19 Years       51.5    -141.42416
# 475  2018  15-19 Years       49.2    -143.72416
#
# [476 rows x 4 columns]

# %%
m_wide = pd.read_pickle('mortality_wide.pkl')
m_wide
# Out:
# AgeGroup  01-04 Years  05-09 Years  10-14 Years  15-19 Years
# Year
# 1900           1983.8        466.1        298.3        484.8
# 1901           1695.0        427.6        273.6        454.4
# 1902           1655.7        403.3        252.5        421.5
# 1903           1542.1        414.7        268.2        434.1
# 1904           1591.5        425.0        305.2        471.4
# ...               ...          ...          ...          ...
# 2014             24.0         11.5         14.0         45.5
# 2015             24.9         11.7         14.6         48.3
# 2016             25.3         12.2         14.6         51.2
# 2017             24.3         11.6         15.5         51.5
# 2018             24.0         11.5         14.9         49.2
#
# [119 rows x 4 columns]

# %%
#3
#m_wide.plot(y=['15-19 years'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 #3
# ----> 2 m_wide.plot(y=['15-19 years'])
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\plotting\_core.py:1016, in PlotAccessor.__call__(self, *args, **kwargs)
#    1013             pass
#    1015 # don't overwrite
# -> 1016 data = data[y].copy()
#    1018 if isinstance(data, ABCSeries):
#    1019     label_name = label_kw or y
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
#4
m_wide.plot.area(legend="reverse")
# Out:
# <Axes: xlabel='Year'>

# %%
#5
m_wide.query("Year == 1900").plot.bar()
# Out:
# <Axes: xlabel='Year'>

# %%
#6
m_wide.query("Year == 2000").plot.bar(title="Mortality rate for year 2000", xlabel="")
# Out:
# <Axes: title={'center': 'Mortality rate for year 2000'}>

# %%
#7
m_data.pivot(index="Year", columns="AgeGroup", values="DeathRate") \
    .query("Year==2000").plot.bar(title="Mortality rate for year 2000", xlabel="")
# Out:
# <Axes: title={'center': 'Mortality rate for year 2000'}>

# %%
#8.1
m_data.plot.hist(y="DeathRate")
# Out:
# <Axes: ylabel='Frequency'>

# %%
#8.2
m_data.plot.hist(y="DeathRate", bins=15)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#9
m_data.query("Year==1900").plot.density(y="DeathRate", title="Mortality rate in the year 1900", xlabel="", grid=True)
# Out:
# <Axes: title={'center': 'Mortality rate in the year 1900'}, ylabel='Density'>

# %%
m_data.query("Year == 1900 or Year == 1925 or Year == 1950 or Year == 1975 or Year == 2000") \
    .groupby("Year")["DeathRate"].sum().plot.pie()
# Out:
# <Axes: ylabel='DeathRate'>

# %%
m_wide.query("Year == 1900 or Year == 1925 or Year == 1950 or Year == 1975 or Year == 2000") \
    .plot.barh(layout=(2,2), subplots=True, sharey=True, grid=True, xlabel="Deathrate")
# Out:
# array([[<Axes: title={'center': '01-04 Years'}, xlabel='Deathrate', ylabel='Year'>,
#         <Axes: title={'center': '05-09 Years'}, xlabel='Deathrate', ylabel='Year'>],
#        [<Axes: title={'center': '10-14 Years'}, xlabel='Deathrate', ylabel='Year'>,
#         <Axes: title={'center': '15-19 Years'}, xlabel='Deathrate', ylabel='Year'>]],
#       dtype=object)
