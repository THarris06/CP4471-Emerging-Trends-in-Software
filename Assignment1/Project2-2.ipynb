# %%
#1
import pandas as pd
data = pd.read_csv("./avocado.csv")

# %%
#2
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
#3
data.nunique()
# Out:
# Unnamed: 0         53
# Date              169
# AveragePrice      259
# Total Volume    18237
# 4046            17702
# 4225            18103
# 4770            12071
# Total Bags      18097
# Small Bags      17321
# Large Bags      15082
# XLarge Bags      5588
# type                2
# year                4
# region             54
# dtype: int64

# %%
#4
data
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
#5.1
data.iloc[[0,1,2,3,4],[0,1,2,3]]
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume
# 0           0  2015-12-27          1.33      64236.62
# 1           1  2015-12-20          1.35      54876.98
# 2           2  2015-12-13          0.93     118220.22
# 3           3  2015-12-06          1.08      78992.15
# 4           4  2015-11-29          1.28      51039.60

# %%
#5.2
data.iloc[[-1,-2,-3,-4,-5],[-1,-2,-3,-4]]
# Out:
#                  region  year     type  XLarge Bags
# 18248  WestTexNewMexico  2018  organic          0.0
# 18247  WestTexNewMexico  2018  organic          0.0
# 18246  WestTexNewMexico  2018  organic          0.0
# 18245  WestTexNewMexico  2018  organic          0.0
# 18244  WestTexNewMexico  2018  organic          0.0

# %%
#6
data[['AveragePrice', 'Total Volume', 'Total Bags']].head(5)
# Out:
#    AveragePrice  Total Volume  Total Bags
# 0          1.33      64236.62     8696.87
# 1          1.35      54876.98     9505.56
# 2          0.93     118220.22     8145.35
# 3          1.08      78992.15     5811.16
# 4          1.28      51039.60     6183.95

# %%
#7
data.Date
# Out:
# 0        2015-12-27
# 1        2015-12-20
# 2        2015-12-13
# 3        2015-12-06
# 4        2015-11-29
#             ...
# 18244    2018-02-04
# 18245    2018-01-28
# 18246    2018-01-21
# 18247    2018-01-14
# 18248    2018-01-07
# Name: Date, Length: 18249, dtype: object

# %%
#8
data['EstimatedRevenue'] = data['Total Volume'] * data['AveragePrice']
data[['EstimatedRevenue']].head(5)
# Out:
#    EstimatedRevenue
# 0        85434.7046
# 1        74083.9230
# 2       109944.8046
# 3        85311.5220
# 4        65330.6880

# %%
#9
df_data = data[['region', 'type', 'AveragePrice']]
df_columns = ['region', 'type', 'AveragePrice']
df = pd.DataFrame(data=df_data, columns=df_columns)
df = df.reset_index();
df.head(5)
# Out:
#    index  region          type  AveragePrice
# 0      0  Albany  conventional          1.33
# 1      1  Albany  conventional          1.35
# 2      2  Albany  conventional          0.93
# 3      3  Albany  conventional          1.08
# 4      4  Albany  conventional          1.28

# %%
#10
data.groupby('year')['Total Volume'].agg(['mean', 'median', 'std']).plot.bar()
# Out:
# <Axes: xlabel='year'>

# %%
#Q1
data.region.nunique()
# Out:
# 54

# %%
#Q2
data.groupby('type')[['AveragePrice']].mean()
# Out:
#               AveragePrice
# type
# conventional      1.158040
# organic           1.653999

# %%
#Q3
data.query("type=='organic'").groupby('region')['AveragePrice'].mean().sort_values(ascending=True).tail(1).reset_index()
# Out:
#                 region  AveragePrice
# 0  HartfordSpringfield      2.229231

# %%
#Q4
data.groupby(['year', 'type'])[['Total Bags']].sum().plot.bar()
# Out:
# <Axes: xlabel='year,type'>
